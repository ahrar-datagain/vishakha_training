# %% [markdown]
# ## Pandas
#
# Pandas is a Python library used for data manipulation and analysis. It provides data structures and functions needed to work with structured data, such as data frames and series.
#
# ### Two main data structures in Pandas
#
# - **Series**: A one-dimensional labeled array.
# - **DataFrame**: A two-dimensional labeled data structure with columns of potentially different types.

# %% [markdown]
# A **DataFrame** is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns) in Python. It is a fundamental data structure in the pandas library, which is widely used for data manipulation and analysis.
#
# ### Key Features of a DataFrame:
# - **Two-Dimensional:** Data is organized in rows and columns, much like a table in a database or an Excel spreadsheet.
# - **Labeled Axes:** Both rows and columns have labels, which are used for accessing and modifying data.
# - **Heterogeneous Data:** Each column in a DataFrame can contain data of different types (e.g., integers, floats, strings).
# - **Size-Mutable:** You can add or remove rows and columns as needed.
# - **Missing Data Handling:** DataFrames have built-in methods for dealing with missing data, such as NaN values.

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}
df = pd.DataFrame(data)
print((df))
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %% [markdown]
# ### Common Operations:
#
# - **Selection:** Accessing specific rows and columns using labels or index positions.
# - **Filtering:** Applying conditions to filter rows.
# - **Aggregation:** Performing statistical operations like sum, mean, etc., on data.
# - **Merging/Joining:** Combining multiple DataFrames.
# - **Reshaping:** Changing the structure of the DataFrame (e.g., pivoting).

# %% [markdown]
# We have taken a movie dataset and we will work on that

# %%
# Path to the uploaded CSV file
file_path = '/kaggle/input/movies/Hydra-Movie-Scrape.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
print(df.head())

# This By default returns the first 5 rows.
# Out:
#                                                Title  Year  \
# 0                        Patton Oswalt: Annihilation  2017
# 1                                      New York Doll  2005
# 2  Mickey's Magical Christmas: Snowed in at the H...  2001
# 3                         Mickey's House of Villains  2001
# 4                                      And Then I Go  2017
#
#                                              Summary  \
# 0  Patton Oswald, despite a personal tragedy, pro...
# 1  A recovering alcoholic and recently converted ...
# 2  After everyone is snowed in at the House of Mo...
# 3  The villains from the popular animated Disney ...
# 4  In the cruel world of junior high, Edwin suffe...
#
#                                        Short Summary  \
# 0  Patton Oswalt, despite a personal tragedy, pro...
# 1  A recovering alcoholic and recently converted ...
# 2  Mickey and all his friends hold their own Chri...
# 3  The villains from the popular animated Disney ...
# 4  In the cruel world of junior high, Edwin suffe...
#
#                                       Genres    IMDB ID  Runtime  \
# 0                              Uncategorized  tt7026230       66
# 1                          Documentary|Music  tt0436629       75
# 2  Adventure|Animation|Comedy|Family|Fantasy  tt0300195       65
# 3     Animation|Comedy|Family|Fantasy|Horror  tt0329374        0
# 4                                      Drama  tt2018111       99
#
#   YouTube Trailer  Rating                                       Movie Poster  \
# 0     4hZi5QaMBFc     7.4  https://hydramovies.com/wp-content/uploads/201...
# 1     jwD04NsnLLg     7.9  https://hydramovies.com/wp-content/uploads/201...
# 2     uCKwHHftrU4     6.8  https://hydramovies.com/wp-content/uploads/201...
# 3     JA03ciYt-Ek     6.6  https://hydramovies.com/wp-content/uploads/201...
# 4     8CdIiD6-iF0     7.6  https://hydramovies.com/wp-content/uploads/201...
#
#             Director        Writers                            Cast
# 0  Bobcat Goldthwait  Patton Oswalt                   Patton Oswalt
# 1      Greg Whiteley    Arthur Kane                 Sylvain Sylvain
# 2         Tony Craig    Thomas Hart  Carlos Alazraqui|Wayne Allwine
# 3     Jamie Mitchell    Thomas Hart      Tony Anselmo|Wayne Allwine
# 4    Vincent Grashaw    Brett Haley        Arman Darbo|Sawyer Barth

# %% [markdown]
# Display all column names

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['Title', 'Year', 'Summary', 'Short Summary', 'Genres', 'IMDB ID',
#        'Runtime', 'YouTube Trailer', 'Rating', 'Movie Poster', 'Director',
#        'Writers', 'Cast'],
#       dtype='object')

# %%
num_rows, num_columns = df.shape
print(f'Number of rows: {num_rows}')
print(f'Number of columns: {num_columns}')
# Out:
# Number of rows: 3940
# Number of columns: 13

# %% [markdown]
# Filter movies that came after 2017

# %%
filtered_df = df[df['Year'] > 2017]
print(filtered_df)
# Out:
#                            Title  Year  \
# 6                   Peter Rabbit  2018
# 10               Forever My Girl  2018
# 11       Tom Segura: Disgraceful  2018
# 15    Suicide Squad: Hell to Pay  2018
# 16                      Wildling  2018
# ...                          ...   ...
# 3923                   Hurricane  2018
# 3924         Destination Wedding  2018
# 3934             Office Uprising  2018
# 3935                  Skyscraper  2018
# 3939                         UFO  2018
#
#                                                 Summary  \
# 6     Based on the books by Beatrix Potter: Peter Ra...
# 10    After being gone for a decade a country star r...
# 11    Comedian Tom Segura rants about funny things a...
# 15    Task Force X targets a powerful mystical objec...
# 16    Anna spends her entire childhood under the car...
# ...                                                 ...
# 3923  1940. Great Britain stands alone in Europe aga...
# 3924  The story of two miserable and unpleasant wedd...
# 3934  An employee at a weapons factory discovers tha...
# 3935  FBI Hostage Rescue Team leader and U.S. war ve...
# 3939  Derek (Alex Sharp) a brilliant college student...
#
#                                           Short Summary  \
# 6     Feature adaptation of Beatrix Potter's classic...
# 10    After being gone for a decade a country star r...
# 11    Comedian Tom Segura rants about funny things a...
# 15    Task Force X targets a powerful mystical objec...
# 16    A blossoming teenager uncovers the dark secret...
# ...                                                 ...
# 3923  Hurricane (Squadron 303) is the story of a gro...
# 3924  The story of two miserable and unpleasant wedd...
# 3934  An employee at a weapons factory discovers tha...
# 3935  A security expert must infiltrate a burning sk...
# 3939  A college student, who sees a UFO, uses his ex...
#
#                                          Genres    IMDB ID  Runtime  \
# 6     Adventure|Animation|Comedy|Family|Fantasy  tt5117670       95
# 10                          Drama|Music|Romance  tt4103724      108
# 11                           Comedy|Documentary  tt7379330        0
# 15                             Action|Animation  tt7167602       86
# 16                               Fantasy|Horror  tt5085924       92
# ...                                         ...        ...      ...
# 3923                                  Drama|War  tt7515456      107
# 3924                       Comedy|Drama|Romance  tt6987770       90
# 3934                       Action|Comedy|Horror  tt6251024       92
# 3935                            Action|Thriller  tt5758778      102
# 3939                     Action|Sci-Fi|Thriller  tt6290798       88
#
#      YouTube Trailer  Rating  \
# 6        7Pa_Weidt08     6.6
# 10       3vqcMr1q5Uc     6.4
# 11       kYYINJM3lPA     7.5
# 15       EPZZvk-wbGE     7.2
# 16       eyl1Wf90AgY     6.1
# ...              ...     ...
# 3923     6s2poY9gTLE     6.0
# 3924     _jrhye68b3M     6.2
# 3934     IfKhTnK_IBA     6.9
# 3935     t9QePUT-Yt8     6.0
# 3939     gxUcHrPhewY     6.2
#
#                                            Movie Poster  \
# 6     https://hydramovies.com/wp-content/uploads/201...
# 10    https://hydramovies.com/wp-content/uploads/201...
# 11    https://hydramovies.com/wp-content/uploads/201...
# 15    https://hydramovies.com/wp-content/uploads/201...
# 16    https://hydramovies.com/wp-content/uploads/201...
# ...                                                 ...
# 3923  https://hydramovies.com/wp-content/uploads/201...
# 3924  https://hydramovies.com/wp-content/uploads/201...
# 3934  https://hydramovies.com/wp-content/uploads/201...
# 3935  https://hydramovies.com/wp-content/uploads/201...
# 3939  https://hydramovies.com/wp-content/uploads/201...
#
#                      Director                  Writers  \
# 6                  Will Gluck               Rob Lieber
# 10        Bethany Ashton Wolf      Bethany Ashton Wolf
# 11                  Jay Karas               Tom Segura
# 15                    Sam Liu             Alan Burnett
# 16                 Fritz Böhm               Fritz Böhm
# ...                       ...                      ...
# 3923              David Blair       Alastair Galbraith
# 3924             Victor Levin             Victor Levin
# 3934               Lin Oeding    Peter Gamble Robinson
# 3935  Rawson Marshall Thurber  Rawson Marshall Thurber
# 3939            Ryan Eslinger            Ryan Eslinger
#
#                                            Cast
# 6                    Fayssal Bazzi|James Corden
# 10    Abby Ryder Fortson|Alex Roe|Jessica Rothe
# 11                                   Tom Segura
# 15            Christian Slater|Vanessa Williams
# 16             Bel Powley|Brad Dourif|Liv Tyler
# ...                                         ...
# 3923    Iwan Rheon|Milo Gibson|Stefanie Martini
# 3924    Dj Dallenbach|Keanu Reeves|Winona Ryder
# 3934      Brenton Thwaites|Jane Levy|Karan Soni
# 3935      Chin Han|Dwayne Johnson|Neve Campbell
# 3939    Alex Sharp|Benjamin Beatty|Ella Purnell
#
# [231 rows x 13 columns]

# %% [markdown]
# Selections in Pandas refer to the various ways you can access, filter, or subset data within a DataFrame or Series. Here’s an overview of the different selection techniques:
#
# ### 1\. **Selecting Columns**
#
# *   Single column

# %%
df['Title'].head(10) # returns series, head() to limit to 10 rows.
# Out:
# 0                          Patton Oswalt: Annihilation
# 1                                        New York Doll
# 2    Mickey's Magical Christmas: Snowed in at the H...
# 3                           Mickey's House of Villains
# 4                                        And Then I Go
# 5                             An Extremely Goofy Movie
# 6                                         Peter Rabbit
# 7                                           Love Songs
# 8                                                   89
# 9                                       The Foster Boy
# Name: Title, dtype: object

# %% [markdown]
# * Multiple Columns

# %%
df[['Title', 'Year']].head(10)  # Returns a DataFrame
# Out:
#                                                Title  Year
# 0                        Patton Oswalt: Annihilation  2017
# 1                                      New York Doll  2005
# 2  Mickey's Magical Christmas: Snowed in at the H...  2001
# 3                         Mickey's House of Villains  2001
# 4                                      And Then I Go  2017
# 5                           An Extremely Goofy Movie  2000
# 6                                       Peter Rabbit  2018
# 7                                         Love Songs  2007
# 8                                                 89  2017
# 9                                     The Foster Boy  2011

# %% [markdown]
# ### 1\. **Selecting Rows**
#
# *   By Index

# %%
df.loc[15]  # Selects a row by its index label
# Out:
# Title                                     Suicide Squad: Hell to Pay
# Year                                                            2018
# Summary            Task Force X targets a powerful mystical objec...
# Short Summary      Task Force X targets a powerful mystical objec...
# Genres                                              Action|Animation
# IMDB ID                                                    tt7167602
# Runtime                                                           86
# YouTube Trailer                                          EPZZvk-wbGE
# Rating                                                           7.2
# Movie Poster       https://hydramovies.com/wp-content/uploads/201...
# Director                                                     Sam Liu
# Writers                                                 Alan Burnett
# Cast                               Christian Slater|Vanessa Williams
# Name: 15, dtype: object

# %% [markdown]
# ### 3\. **Selecting Rows and Columns Together**

# %%
a = df.loc[15, 'Title']# Select a specific cell by row label and column name
b = df.loc[15, ['Title', 'Year']]  # Select specific row and multiple columns
c = df.loc[:, ['Title', 'Year']].head(10)  # Select all rows but specific columns

print(a)
print("**********************")
print(b)
print("**********************")
print(c)
# Out:
# Suicide Squad: Hell to Pay
# **********************
# Title    Suicide Squad: Hell to Pay
# Year                           2018
# Name: 15, dtype: object
# **********************
#                                                Title  Year
# 0                        Patton Oswalt: Annihilation  2017
# 1                                      New York Doll  2005
# 2  Mickey's Magical Christmas: Snowed in at the H...  2001
# 3                         Mickey's House of Villains  2001
# 4                                      And Then I Go  2017
# 5                           An Extremely Goofy Movie  2000
# 6                                       Peter Rabbit  2018
# 7                                         Love Songs  2007
# 8                                                 89  2017
# 9                                     The Foster Boy  2011

# %% [markdown]
# ### 4\. **Boolean Indexing (Conditional Selection)**
#
# *   Select Rows based on a condition

# %%
df[df['Year'] > 2015].head(10)  # Select rows where the condition is True
# Out:
#                           Title  Year  \
# 0   Patton Oswalt: Annihilation  2017
# 4                 And Then I Go  2017
# 6                  Peter Rabbit  2018
# 8                            89  2017
# 10              Forever My Girl  2018
# 11      Tom Segura: Disgraceful  2018
# 14                 Silent Night  2017
# 15   Suicide Squad: Hell to Pay  2018
# 16                     Wildling  2018
# 17          The Humanity Bureau  2017
#
#                                               Summary  \
# 0   Patton Oswald, despite a personal tragedy, pro...
# 4   In the cruel world of junior high, Edwin suffe...
# 6   Based on the books by Beatrix Potter: Peter Ra...
# 8   89 tells the incredible story of one of footba...
# 10  After being gone for a decade a country star r...
# 11  Comedian Tom Segura rants about funny things a...
# 14  Adam unexpectedly visits his family house at C...
# 15  Task Force X targets a powerful mystical objec...
# 16  Anna spends her entire childhood under the car...
# 17  A dystopian thriller set in the year 2030 that...
#
#                                         Short Summary  \
# 0   Patton Oswalt, despite a personal tragedy, pro...
# 4   In the cruel world of junior high, Edwin suffe...
# 6   Feature adaptation of Beatrix Potter's classic...
# 8   The true story of a sporting miracle, when Ars...
# 10  After being gone for a decade a country star r...
# 11  Comedian Tom Segura rants about funny things a...
# 14  Adam unexpectedly visits his family house at C...
# 15  Task Force X targets a powerful mystical objec...
# 16  A blossoming teenager uncovers the dark secret...
# 17  A dystopian thriller set in the year 2030 that...
#
#                                        Genres    IMDB ID  Runtime  \
# 3713  A woman is hired as a handmaiden to a Japanese...
# 3716  The Avengers and their allies must be willing ...
# 3762  A young man is ostracized by his classmates af...
# 3797  An exploration of the life, lessons, and legac...
# 3807  Insia is a 14 year-old from Vadodara who dream...
# 3827  Upon realizing the extent to which women are a...
#
#                                          Genres    IMDB ID  Runtime  \
# 8                                 Uncategorized  tt7614404       91
# 21                                  Documentary  tt6543420       85
# 125                                 Documentary  tt6333054       93
# 127                         Documentary|History  tt6223974      121
# 186             Animation|Drama|Fantasy|Romance  tt5311514      106
# 192                                 Crime|Drama  tt5027774      115
# 221   Adventure|Animation|Comedy|Family|Fantasy  tt2380307        0
# 238                                 Documentary  tt7320560      113
# 260               Drama|Mystery|Sci-Fi|Thriller  tt1856101      164
# 439                Action|Drama|Sci-Fi|Thriller  tt3315342      137
# 461           Action|Comedy|Drama|Music|Musical  tt3783958      128
# 470                             Biography|Drama  tt3741834      118
# 499          Action|Biography|Drama|History|War  tt2119532      139
# 527                              Action|Musical  tt6162808      141
# 2813               Action|Biography|Drama|Sport  tt5074352      161
# 3426                                  Drama|War  tt5813916      135
# 3434                        Documentary|Mystery  tt5165878       85
# 3465                                Documentary  tt3638960      101
# 3466                          Documentary|Music  tt6212934        0
# 3502   Adventure|Animation|Comedy|Drama|Fantasy  tt5104604      101
# 3636                                Documentary  tt8638420       98
# 3640                                Documentary  tt7689966        0
# 3647                       Action|Drama|History  tt6826438      129
# 3682                       Action|Drama|Fantasy  tt4849438      167
# 3713       Crime|Drama|Mystery|Romance|Thriller  tt4016934      144
# 3716            Action|Adventure|Fantasy|Sci-Fi  tt4154756      149
# 3762             Animation|Drama|Family|Romance  tt5323662      130
# 3797                      Biography|Documentary  tt7681902       94
# 3807                                Drama|Music  tt6108090      150
# 3827                            Biography|Drama  tt7218518      140
#
#      YouTube Trailer  Rating  \
# 8        5hfAExhHTMM     8.1
# 21       f_jTeuajas0     8.2
# 125      b6fHA9R2cKI     8.1
# 127      znTdk_de_K8     8.1
# 186      VgixlvX28-g     8.4
# 192      Jit3YhGx5pU     8.2
# 221      6Zxj9q8Yjdw     8.5
# 238      lsZ8hDutkeM     8.2
# 260      gCcx85zbxz4     8.1
# 439      DekuSxJgpbY     8.1
# 461      0pdqf4P9MB8     8.1
# 470      -RNI9o06vqo     8.1
# 499      s2-1hz1juBI     8.2
# 527      nj9lxgsSTT4     8.1
# 2813     x_7YlGv9u1g     8.5
# 3426     jpByS8cbcVA     9.5
# 3434     saDtU_-H_xY     8.6
# 3465     4ZJEMYjsPqI     8.1
# 3466     YRysoVz4JZk     8.1
# 3502     dt__kig8PVU     8.2
# 3636     q2UYQJmMIxc     8.2
# 3640     caIFNg_JRL4     8.2
# 3647     XQFb12N0Arc     8.4
# 3682     qD-6d8Wo3do     8.4
# 3713     whldChqCsYk     8.1
# 3716     6ZfuNTqbHE8     8.7
# 3762     twUSlecQpGQ     8.2
# 3797     FhwktRDG_aQ     8.7
# 3807     P6jaRsnchro     8.1
# 3827     -K9ujx8vO_A     8.1
#
# 127               Carolyn Porco|Frank Drake|John Casani
# 186                 Mone Kamishiraishi|Ryûnosuke Kamiki
# 192      Frances McDormand|Sam Rockwell|Woody Harrelson
# 221                 Anthony Gonzalez|Gael García Bernal
# 238                                                 NaN
# 260                          Harrison Ford|Ryan Gosling
# 439                        Hugh Jackman|Patrick Stewart
# 461            Emma Stone|Rosemarie DeWitt|Ryan Gosling
# 470                 Dev Patel|Nicole Kidman|Rooney Mara
# 499         Andrew Garfield|Luke Bracey|Sam Worthington
# 527      Alistair Brammer|Eva Noblezada|Jon Jon Briones
# 2813                           Aamir Khan|Sakshi Tanwar
# 3426                   Bedii Akin|Murat Arkin|Ozan Agaç
# 3434  Dr. Marc Edwards|Dr. Mona Hanna-Attisha|Dr. Ra...
# 3465                           Bruce Parry|Ingrid Lewis
# 3466                                      Dave Catching
# 3502                         Bryan Cranston|Koyu Rankin
# 3636                                         Björn Borg
# 3640                                      Robert Altman
# 3647                           Boman Irani|John Abraham
# 3682                             Prabhas|Rana Daggubati
# 3713                            Jung-woo Ha|Min-hee Kim
# 3716                  Chris Hemsworth|Robert Downey Jr.
# 3762                            Miyu Irino|Saori Hayami
# 3797        Betty Aberlin|David Bianculli|Joanne Rogers
# 3807                    Meher Vij|Raj Arjun|Zaira Wasim
# 3827             Akshay Kumar|Radhika Apte|Sonam Kapoor

# %% [markdown]
# ### 5\. **Selecting With Query**

# %%
# This will filter titles that start with a letter 'P' alphabetically
# df_filtered = df[df['Title'].str[0] == 'P']

# get only title and year column not whole rows
df_filtered = df.query("Title.str[0] == 'P'")[['Title', 'Year', 'Rating']].head(10)
print(df_filtered)
# Out:
#                            Title  Year  Rating
# 0    Patton Oswalt: Annihilation  2017     7.4
# 6                   Peter Rabbit  2018     6.6
# 32             Perfect Strangers  2017     7.0
# 33                       Paterno  2018     6.6
# 41            Petals on the Wind  2014     6.3
# 66                Phantom Thread  2017     7.7
# 115                      Prodigy  2017     6.6
# 116              Pitch Perfect 3  2017     6.0
# 119              Pan's Labyrinth  2006     8.2
# 124                 Paddington 2  2017     8.0

# %%
# for Multiple Conditions
df_filtered = df.query("Title.str[0] == 'P' and Rating > 7")[['Title','Rating']].head(10)  # Multiple conditions
print(df_filtered)
# Out:
#                                                  Title  Rating
# 0                          Patton Oswalt: Annihilation     7.4
# 66                                      Phantom Thread     7.7
# 119                                    Pan's Labyrinth     8.2
# 124                                       Paddington 2     8.0
# 244  Phineas and Ferb the Movie: Across the 2nd Dim...     7.5
# 255             Professor Marston and the Wonder Women     7.1
# 432                                   Peaceful Warrior     7.3
# 472                                           Paterson     7.4
# 475                                       Patriots Day     7.4
# 654                            Pelé: Birth of a Legend     7.2

# %% [markdown]
# ### 6\. **Selecting Specific Columns Using Column Name Patterns**
#
# *   **Using .filter()**

# %%
df.filter(like='er')  # Selects columns with names containing 'substring'
# df.filter(regex='regex_pattern')  # Selects columns based on a regular expression
# Out:
#      YouTube Trailer                                       Movie Poster  \
# 0        4hZi5QaMBFc  https://hydramovies.com/wp-content/uploads/201...
# 1        jwD04NsnLLg  https://hydramovies.com/wp-content/uploads/201...
# 2        uCKwHHftrU4  https://hydramovies.com/wp-content/uploads/201...
# 3        JA03ciYt-Ek  https://hydramovies.com/wp-content/uploads/201...
# 4        8CdIiD6-iF0  https://hydramovies.com/wp-content/uploads/201...
# ...              ...                                                ...
# 3935     t9QePUT-Yt8  https://hydramovies.com/wp-content/uploads/201...
# 3936     bVDGukfxFAk  https://hydramovies.com/wp-content/uploads/201...
# 3937     bv0Eh2VhTTA  https://hydramovies.com/wp-content/uploads/201...
# 3938     8TKLR1_JVLU  https://hydramovies.com/wp-content/uploads/201...
# 3939     gxUcHrPhewY  https://hydramovies.com/wp-content/uploads/201...
#
#                       Writers
# 0               Patton Oswalt
# 1                 Arthur Kane
# 2                 Thomas Hart
# 3                 Thomas Hart
# 4                 Brett Haley
# ...                       ...
# 3935  Rawson Marshall Thurber
# 3936                Matt Booi
# 3937            Joseph Nasser
# 3938             Mark Zakarin
# 3939            Ryan Eslinger
#
# [3940 rows x 3 columns]

# %% [markdown]
# ### Filtering in Pandas: Overview and Methods
#
# **Filtering** in Pandas involves selecting a subset of rows from a DataFrame based on specific conditions. It’s a fundamental operation for data analysis, allowing you to isolate the data you need for further processing or analysis.
#
# **Methods**:
#
# *   **Single Condition Filtering**:
#
#     *   Select rows based on a condition applied to one column (e.g., all rows where a column value is above a threshold).
#
# *   **Multiple Condition Filtering**:
#
#     *   Combine conditions using logical operators like AND (&), OR (|), and NOT (~) to refine the selection.
#
# *   **String-Based Filtering**:
#
#     *   Filter rows based on string patterns, such as whether a string starts with, ends with, or contains a certain substring.
#
# *   **Filtering with .isin()**:
#
#     *   Select rows where a column’s value is in a list of specific values.
#
# *   **Range Filtering with .between()**:
#
#     *   Filter rows where a column’s value lies within a specific range.
#
# *   **SQL-like Filtering with query()**:
#
#     *   Use a more readable, SQL-like syntax to filter DataFrames based on conditions.
#
# *   **Handling Missing Data**:
#
#     *   Filter out rows with missing data using .isnull(), .notnull(), and .dropna().
#
# *   **Filtering Duplicates**:
#
#     *   Identify and filter out duplicate rows based on one or more columns.
#
# *   **Top/Bottom N Filtering**:
#
#     *   Select the largest or smallest N values in a column using .nlargest() and .nsmallest().

# %% [markdown]
# ### Grouping in Pandas
#
# **Grouping** in Pandas allows you to aggregate and analyze data by grouping it based on one or more columns. This is useful for summarizing data and performing calculations on subsets of your dataset.
#
# #### Key Points:
#
# 1.  **Key Functions**:
#
#     *   **groupby()**: Main function to group data by one or more columns.
#
#     *   **Aggregation Functions**: Functions like sum(), mean(), count(), min(), max(), etc., to calculate statistics on each group.
#
#     *   **Transformation Functions**: Functions like transform() and apply() to perform operations on each group.
#
# 2.  **Common Operations**:
#
#     *   **Grouping by Columns**: Group data based on values in one or more columns.
#
#     *   **Applying Aggregations**: Calculate statistics like mean, sum, or count for each group.
#
#     *   **Filtering Groups**: Apply conditions to filter groups based on aggregate results

# %%
# Dummy Data
data = {
    'Department': ['HR', 'HR', 'Finance', 'Finance', 'IT', 'IT', 'IT'],
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace'],
    'Salary': [70000, 75000, 80000, 85000, 90000, 95000, 100000],
    'Experience': [2, 5, 7, 8, 3, 6, 9]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Department Employee  Salary  Experience
# 0         HR    Alice   70000           2
# 1         HR      Bob   75000           5
# 2    Finance  Charlie   80000           7
# 3    Finance    David   85000           8
# 4         IT      Eve   90000           3
# 5         IT    Frank   95000           6
# 6         IT    Grace  100000           9

# %% [markdown]
# #### Q1. Group by Department and compute the sum salary and exp for each department

# %%
grouped_df = df.groupby('Department').sum()
print("\nGrouped DataFrame:")
print(grouped_df)
# Out:
# Grouped DataFrame:
#                  Employee  Salary  Experience
# Department
# Finance      CharlieDavid  165000          15
# HR               AliceBob  145000           7
# IT          EveFrankGrace  285000          18

# %% [markdown]
# #### Q2. Group by dept and get mean of salary and experience?

# %%
g = df.groupby('Department')
c = g[['Salary', 'Experience']].mean()
print(c)
# Out:
#              Salary  Experience
# Department
# Finance     82500.0         7.5
# HR          72500.0         3.5
# IT          95000.0         6.0

# %% [markdown]
# #### Q3. Add a new column that shows mean salary of each dept

# %%
df['Mean_Salary'] = g['Salary'].transform('mean')
print(df)
# Out:
#   Department Employee  Salary  Experience  Mean_Salary
# 0         HR    Alice   70000           2      72500.0
# 1         HR      Bob   75000           5      72500.0
# 2    Finance  Charlie   80000           7      82500.0
# 3    Finance    David   85000           8      82500.0
# 4         IT      Eve   90000           3      95000.0
# 5         IT    Frank   95000           6      95000.0
# 6         IT    Grace  100000           9      95000.0

# %% [markdown]
# In pandas, merging is the process of combining two or more DataFrames based on a common key or index. It is similar to SQL joins and allows you to integrate data from different sources into a single DataFrame.
#
# ### Key Points:
#
# *   **merge() Function**: The primary function used for merging DataFrames.
#
# *   **Keys**: Merging is done based on common columns (keys) or indices.
#
# *   **Types of Joins**: Supports different join types such as inner, outer, left, and right joins.
#
#
# For example, merging can combine employee details from one DataFrame with department information from another based on a common 'Department\_ID'

# %%
department_data = {
    'Department': ['HR', 'Finance', 'IT'],
    'Department_ID': [10, 20, 30],
    'Location': ['Building A', 'Building B', 'Building C']
}

df_department = pd.DataFrame(department_data)

# Merge the two DataFrames on the 'Department' column
merged_df = pd.merge(df, df_department, on='Department', how='inner')

print(merged_df)
# Out:
#   Department Employee  Salary  Experience  Mean_Salary  Department_ID  \
# 0         HR    Alice   70000           2      72500.0             10
# 1         HR      Bob   75000           5      72500.0             10
# 2    Finance  Charlie   80000           7      82500.0             20
# 3    Finance    David   85000           8      82500.0             20
# 4         IT      Eve   90000           3      95000.0             30
# 5         IT    Frank   95000           6      95000.0             30
# 6         IT    Grace  100000           9      95000.0             30
#
#      Location
# 0  Building A
# 1  Building A
# 2  Building B
# 3  Building B
# 4  Building C
# 5  Building C
# 6  Building C

# %% [markdown]
# In the above code:
# *   **on='Department'**: Specifies that the merging should be done based on the Department column, which is common in both DataFrames.
#
# *   **how='inner'**: Specifies an inner join, meaning that only the rows with matching Department values in both DataFrames will be included in the merged result.
